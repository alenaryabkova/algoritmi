# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import math
import json 
data = json.load(open("C:\\Users\\Alena\\Desktop\\dpc-covid19-ita-province.json"))

# %%
covid=pd.DataFrame(data)
covid
# Out:
#                       data stato  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00   ITA              13               Abruzzo
# 1      2020-02-24T18:00:00   ITA              13               Abruzzo
# 2      2020-02-24T18:00:00   ITA              13               Abruzzo
# 3      2020-02-24T18:00:00   ITA              13               Abruzzo
# 4      2020-02-24T18:00:00   ITA              13               Abruzzo
# ...                    ...   ...             ...                   ...
# 21124  2020-07-31T17:00:00   ITA               5                Veneto
# 21125  2020-07-31T17:00:00   ITA               5                Veneto
# 21126  2020-07-31T17:00:00   ITA               5                Veneto
# 21127  2020-07-31T17:00:00   ITA               5                Veneto
# 21128  2020-07-31T17:00:00   ITA               5                Veneto
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# ...
